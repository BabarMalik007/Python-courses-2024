# %% [markdown]
# # What is Object Oriented Programming?

# %% [markdown]
# # - Paradigms of Prgramming
#                   - procedural programming
#                   - Functional programming
#                   - Object oriented programming

# %% [raw]
# Object oriented programming –
#     The program is written as a collection of classes and object which are meant for communication.
#     The smallest and basic entity is object and all kind of computation is performed on the objects only.
#     More emphasis is on data rather procedure.
#     It can handle almost all kind of real life problems which are today in scenario.
#
#
# Advantages:
#     - Data security
#     - Inheritance
#     - Code reusability
#     - Flexible and abstraction is also present

# %% [markdown]
# # What is Object in OPP?

# %% [markdown]
# from now everything in pyhon is OBJECT. Object is an instance(copy) of class.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Define A class and Creating objects of class

# %%
a  = 1000

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(self, /)
#  |      Returns size in memory, in bytes.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  as_integer_ratio(self, /)
#  |      Return integer ratio.
#  |
#  |      Return a pair of integers, whose ratio is exactly equal to the original int
#  |      and with a positive denominator.
#  |
#  |      >>> (10).as_integer_ratio()
#  |      (10, 1)
#  |      >>> (-10).as_integer_ratio()
#  |      (-10, 1)
#  |      >>> (0).as_integer_ratio()
#  |      (0, 1)
#  |
#  |  bit_count(self, /)
#  |      Number of ones in the binary representation of the absolute value of self.
#  |
#  |      Also known as the population count.
#  |
#  |      >>> bin(13)
#  |      '0b1101'
#  |      >>> (13).bit_count()
#  |      3
#  |
#  |  bit_length(self, /)
#  |      Number of bits necessary to represent self in binary.
#  |
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  to_bytes(self, /, length=1, byteorder='big', *, signed=False)
#  |      Return an array of bytes representing an integer.
#  |
#  |      length
#  |        Length of bytes object to use.  An OverflowError is raised if the
#  |        integer is not representable with the given number of bytes.  Default
#  |        is length 1.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.  Default is to use 'big'.
#  |      signed
#  |        Determines whether two's complement is used to represent the integer.
#  |        If signed is False and a negative integer is given, an OverflowError
#  |        is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_bytes(bytes, byteorder='big', *, signed=False) from builtins.type
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      bytes
#  |        Holds the array of bytes to convert.  The argument must either
#  |        support the buffer protocol or be an iterable object producing bytes.
#  |        Bytes and bytearray are examples of built-in objects that support the
#  |        buffer protocol.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.  Default is to use 'big'.
#  |      signed
#  |        Indicates whether two's complement is used to represent the integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number

# %% [markdown]
# a is an object of int class

# %%
lst = [1,2,3]

# %% [markdown]
# lst is an object of list class

# %%
dic = {'name':'nasir'}

# dic is an object of dicionary

# %%
print(type(dic))
# Out:
# <class 'dict'>

# %% [markdown]
# class Human():
#
#     # properties
#         - gender
#         - blood gp
#         - age
#         - height
#         - weight
#         - name
#         - contact
#
#     # behaviours
#
#          - eat()
#          - sleep()
#          - walk()
#          - weep()

# %%
class Human():
    # attributes (variables)
    name  = "atif"
    age  = 10
    height_cm = 100
    weight_kg = 30
    contact = '12345689'
    
    # behaiours (function>> methods)
    def walk(self):
        print("Human is walking")
    def sleep(self):
        print("Human is sleeping")

# %% [markdown]
# # Creating object of Class

# %%
hum1 = Human()

# %%
print(type(hum1))
# Out:
# <class '__main__.Human'>

# %%
hum1.name
# Out:
# 'atif'

# %%
hum1.age
# Out:
# 10

# %%
hum1.walk()
# Out:
# Human is walking

# %%
hum1.sleep()
# Out:
# Human is sleeping

# %%
hum2 = Human()

# %%
hum2.name
# Out:
# 'atif'

# %%
hum2.age
# Out:
# 10

# %%
class Laptop():
    company = 'Lenovo'
    model   = 'ideapad330S'
    ram     = '20Gb'
    storage = '1.5Tb'
    color   = 'deepblue'
    processor= 'corei7'
    generation = "11gen"
    windows   = "win11"
    
    def on(self):
        print("Laptop is switching ON")
    def off(self):
        print("Laptop is switching OFF")
        
    def internet_surf(self):
        print("Internet is surfing on laptop")
        
    def coding(self):
        print("Code is written and executed on laptop")

# %%
huzaifa_laptop = Laptop()

# %%
adil_laptop = Laptop()

# %%
nasir_laptop = Laptop()

# %%
nasir_laptop.windows
# Out:
# 'win11'

# %%
adil_laptop.processor
# Out:
# 'corei7'

# %% [markdown]
# # Initializer / Contructor: it provides values to  object

# %%
class Laptop():
    
    
#     company = 'Lenovo'
#     model   = 'ideapad330S'
#     ram     = '20Gb'
#     storage = '1.5Tb'
#     color   = 'deepblue'
#     processor= 'corei7'
#     generation = "11gen"
#     windows   = "win11"
    
    def on(self):
        print("Laptop is switching ON")
    def off(self):
        print("Laptop is switching OFF")
        
    def internet_surf(self):
        print("Internet is surfing on laptop")
        
    def coding(self):
        print("Code is written and executed on laptop")

# %%
class Car():
    name = 'Corolla'
    engine = '1500CC'
    year = 2020
    model  = 2018
    
    def start(self):
        print("Car starts")
    def off(self):
        print("Car Off")

# %%
car_atif = Car()

# %%
taha_car = Car()

# %%
car_atif.model
# Out:
# 2018

# %%
taha_car.model
# Out:
# 2018

# %%
class Car():
    def __init__(self,model,make,year, engine_type, color,cc):
        self.model = model
        self.make = make
        self.year = year
        self.engine_type = engine_type
        self.color =color
        self.cc = cc  
        
    def start_car(self):
        print(f"{self.make} {self.model} is starting")
    def stop_car(self):
        print(f"{self.make} {self.model} is stopping")

# %%
atif_car = Car('Civic', 'Honda', 2024, 'Diesel', 'Black', '1800')

# %%
taha_car = Car('Charger', 'Dodge', '2024', 'Diesel', 'Red', '3500')

# %%
atif_car.color
# Out:
# 'Black'

# %%
taha_car.color
# Out:
# 'Red'

# %%
atif_car.start_car()
# Out:
# Honda Civic is starting

# %%
 taha_car.start_car()
# Out:
# Dodge Charger is starting

# %%
Car.start_car(taha_car)
# Out:
# Dodge Charger is starting

# %%
class Bank():
    def __init__(self, branch_code, branch_name, manger_name, deposit):
        self.branch_code = branch_code
        self.branch_name = branch_name
        self.manger_name = manger_name
        self.deposit = deposit
        self.accounts = []
        self.number_of_accounts = 0
        
    def open_account(self,name,amt):
        
        print(f"""
              Account Opened
              
              Title: {name}
              Balance: {amt}
              
              
              """)
        self.accounts.append({'name':name, "amt":amt})
        self.number_of_accounts +=1
        self.deposit +=amt
        
    def branch_desc(self):
        print(f"""
        
        Branch Code: {self.branch_code}
        Branch Name: {self.branch_name}
        Manager Name: {self.manger_name}
        Branch Deposit: {self.deposit}
        
        Number_of Acc: {self.number_of_accounts}
        
        """)
        
        
        
        
        
        
br1 = Bank(1002, 'Dhoraji Branch', 'Maaz', 100000000) 
br2 = Bank(1003, 'Chicago Branch', 'Mudasir', 600000000) 
br3 = Bank(1004, 'Berlin Branch', 'Okasha', 300000000)

# %%
 br1.branch_desc()
# Out:
#
#         Branch Code: 1002
#         Branch Name: Dhoraji Branch
#         Manager Name: Maaz
#         Branch Deposit: 100000000
#
#         Number_of Acc: 0

# %%
br2.branch_desc()
# Out:
#
#         Branch Code: 1003
#         Branch Name: Chicago Branch
#         Manager Name: Mudasir
#         Branch Deposit: 600000000
#
#         Number_of Acc: 0

# %%
br1.open_account('Nasir Hussain', 555000)
# Out:
#               Account Opened
#
#               Title: Nasir Hussain
#               Balance: 555000

# %%
br1.branch_desc()
# Out:
#
#         Branch Code: 1002
#         Branch Name: Dhoraji Branch
#         Manager Name: Maaz
#         Branch Deposit: 100555000
#
#         Number_of Acc: 1

# %%
br1.accounts
# Out:
# [{'name': 'Nasir Hussain', 'amt': 555000}]

# %%
br1.open_account('Shahbaz Sharif', 354565)
br1.branch_desc()
br1.accounts
# Out:
#               Account Opened
#
#               Title: Shahbaz Sharif
#               Balance: 354565
#
#
#
#
#
#         Branch Code: 1002
#         Branch Name: Dhoraji Branch
#         Manager Name: Maaz
#         Branch Deposit: 100909565
#
#         Number_of Acc: 2
# [{'name': 'Nasir Hussain', 'amt': 555000},
#  {'name': 'Shahbaz Sharif', 'amt': 354565}]

# %%
br2.open_account('Faraz', 50000)
# Out:
#               Account Opened
#
#               Title: Faraz
#               Balance: 50000

# %%
br1.open_account('Yasir Hussain', 1000000)
# Out:
#               Account Opened
#
#               Title: Yasir Hussain
#               Balance: 1000000

# %%
class Laptop():
    def __init__(self,comp, model, gen, storage, ram,pro,price):
        self.comp = comp
        self.model =model
        self.gen = gen
        self.storage = storage
class        self.ram =ram
        self.pro =pro
        self.price = price
    def specs(self):
        print(f"""
        
            Company : {self.comp}
             Model:    {self.model}
            Generation: {self.gen}
            Storage:    {self.storage}
            Ram :       {self.ram}
            Processor:   {self.pro}
            Price:     {self.price}""")
    def play_games(self):
        print("I am playing games")

# %%
maaz = Laptop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 maaz = Laptop()
#
# TypeError: Laptop.__init__() missing 7 required positional arguments: 'comp', 'model', 'gen', 'storage', 'ram', 'pro', and 'price'

# %%
maaz  =Laptop('Dell','n1245',"7th", "1Tb","16Gb", 'intel corei7',60000)

# %%
maaz.specs()
# Out:
#
#             Company : Dell
#             Model:    n1245
#             Generation: 7th
#             Storage:    1Tb
#             Ram :       16Gb
#             Processor:   intel corei7
#             Price:     60000

# %%
nasir  =Laptop('Lenovo','330s',"7th", "1Tb","16Gb", 'intel corei7',160000)

# %%
nasir.specs()
# Out:
#
#             Company : Lenovo
#             Model:    330s
#             Generation: 7th
#             Storage:    1Tb
#             Ram :       16Gb
#             Processor:   intel corei7
#             Price:     160000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Encapsulation
#          - Binding data with methods.

# %%
maaz.ram
# accessing the data in class outside the class
# Out:
# '16Gb'

# %%
maaz.ram = "160Gb"

# %%
maaz.specs()
# Out:
#
#             Company : Dell
#             Model:    n1245
#             Generation: 7th
#             Storage:    1Tb
#             Ram :       160Gb
#             Processor:   intel corei7
#             Price:     60000

# %% [markdown]
# # Encapsulation

# %%
class Laptop():
    def __init__(self,comp, model, gen, storage, ram,pro,price):
        self.comp = comp
        self.model =model
        self.gen = gen
        self.storage = storage
        self.ram =ram
        self.pro =pro
        self.price = price
    def specs(self):
        print(f"""
        
            Company : {self.comp}
            Model:    {self.model}
            Generation: {self.gen}
            Storage:    {self.storage}
            Ram :       {self.ram}
            Processor:   {self.pro}
            Price:     {self.price}""")
    def play_games(self):
        print("I am playing games")
           
    def get_comp(self):
        return self.comp
    def set_comp(self,new_comp):
        companies = ['lenovo', 'dell', 'hp']
        if new_comp in companies:
            self.comp = new_comp
        else:
            print("Not a valid company")

# %%
lap1 = Laptop('Dell','n1245',"7th", "1Tb","16Gb", 'intel corei7',60000)

# %%
lap1.specs()
# Out:
#
#             Company : Dell
#             Model:    n1245
#             Generation: 7th
#             Storage:    1Tb
#             Ram :       16Gb
#             Processor:   intel corei7
#             Price:     60000

# %%
lap1.set_comp("Lifeboye")
# Out:
# Not a valid company

# %%
lap1.set_comp("hp")

# %%
lap1.get_comp()
# Out:
# 'hp'

# %% [markdown]
# # Inheritance

# %%
class Abba():
    def __init__(self, name,age,blood_gp, height,complexion):
        self.name = name
        self.age = age
        self.blood_gp = blood_gp
        self.height =height
        self.complexion =complexion
    def job(self):
        print("KE")
    def drive(self):
        print("KE ka truck")

# %%
maaz = Abba('maazabba',50, 'B+',"6ft",'Fair')

# %%
maaz.job()
# Out:
# KE

# %%
maaz.drive()
# Out:
# KE ka truck

# %%
claclass Bacha(Abba):
    pass

# %%
taha = Bacha('taha',, 'B+',"6ft",'Fair')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 taha = Bacha()
#
# TypeError: Abba.__init__() missing 5 required positional arguments: 'name', 'age', 'blood_gp', 'height', and 'complexion'

# %%
class Car():
    def __init__(self, make, model, year='2024'):
        self.make = make
        self.model = model
        self.year = year
    
    def get_descriptive_name(self):        
        return f"{self.year}{self.make}{self.model}".title()
    
    
my_new_car = Car('audi', 'a4',2025)

print(my_new_car.get_descriptive_name())
# Out:
# 2025Audia4

# %% [markdown]
# # Setting a Default Value for an Attribute

# %%
def add(a,b=0):
    return a+b
add(100)
# Out:
# 100

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading=0
        
    
    def get_descriptive_name(self):
        return f"{self.year} {self.make} {self.model}".title()

    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")

# %%
my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
# Out:
# 2016Audia4

# %%
my_new_car.read_odometer()
# Out:
# This car has 0 miles on it.

# %% [markdown]
# # Modifying Attribute Values

# %% [markdown]
# ### Modifying an Attribute’s Value Directly

# %%
my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# This car has 23 miles on it.

# %% [markdown]
# ### Modifying an Attribute’s Value Through a Method

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading=0        
    
    def get_descriptive_name(self):
        return f"{self.year} {self.make} {self.model}".title()
    def set_odometer(self, new_reading):
        if new_reading < self.odometer_reading:
            print("Cheater insan ban ja.")
        else:
            self.odometer_reading = new_reading

    def get_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")

# %%
my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
# Out:
# 2016 Audi A4

# %%
my_new_car.get_odometer()
# Out:
# This car has 0 miles on it.

# %%
my_new_car.set_odometer(10)

# %%
my_new_car.get_odometer()
# Out:
# This car has 10 miles on it.

# %%
my_new_car.set_odometer(5)
# Out:
# Cheater insan ban ja.

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)

# %%
my_tesla = ElectricCar('tesla', 'model s', 2024)
print(my_tesla.get_descriptive_name())
# Out:
# 2024 Tesla Model S

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery_size =  70
    def describe_battery(self):
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)

print(my_tesla.get_descriptive_name())

my_tesla.describe_battery()
# Out:
# 2016 Tesla Model S
# This car has a 70-kWh battery.

# %% [markdown]
# ### Overriding Methods from the Parent Class

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading=0        
    
    def get_descriptive_name(self):
        return f"{self.year} {self.make} {self.model}".title()
    def set_odometer(self, new_reading):
        if new_reading < self.odometer_reading:
            print("Cheater insan ban ja.")
        else:
            self.odometer_reading = new_reading

    def get_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")
        
    def fill_gas_tank(self):
        print("OK car tank is being filled with gasoline")

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery_size =  70
    def describe_battery(self):
        print("This car has a " + str(self.battery_size) + "-kWh battery.")
    def fill_gas_tank(self):
        print("There is no gas tank needed in Electric Car")

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)

# %%
my_tesla.fill_gas_tank()
# Out:
# There is no gas tank needed in Electric Car

# %%
def add(a,b=0):
    return a+b
add(100)
# Out:
# 100

# %%
def add(a,b,c):
    return a + b+ c

# %%
add()

# %%
1+2
# Out:
# 3

# %%
"1"+"2"
# Out:
# '12'

# %%
len("hello")
# Out:
# 5

# %%
len([1,2,3])
# Out:
# 3

# %% [markdown]
# # Object as Attribute
